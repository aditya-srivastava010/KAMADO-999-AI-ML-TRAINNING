# %% [markdown]
# <a href="https://colab.research.google.com/github/KAMADO-999/KAMADO-999-AI-ML-TRAINNING/blob/main/day3_practice_handout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***LIST-Q1***

# %%
marks = [72, 65, 88, 90, 65]
a=max(marks)
#second approach
maximum=marks[0]
for i in marks:
  if i>max:
    maximum=i
maximum
# Out:
# 90

# %% [markdown]
# # ***LIST-Q2***

# %%
marks = [72, 65, 88, 90]
marks.append(100)
marks.sort()
marks.reverse()
marks
# Out:
# [100, 90, 88, 72, 65]

# %% [markdown]
# # ***LIST-Q3***

# %%
marks = [72, 65, 88, 90, 65]
marks.remove(65)
marks
# Out:
# [72, 88, 90, 65]

# %% [markdown]
# #***STRINGS***

# %% [markdown]
# #***STRING-Q4***

# %%
s = "machine learning"
cap1=s.capitalize()
cap2=s.title()
print(cap1)
print(cap2)
# Out:
# Machine learning
# Machine Learning

# %% [markdown]
# #***STRING-Q5***

# %%
s="data,model,train,test"
l1=s.split(",")
l1
# Out:
# ['data', 'model', 'train', 'test']

# %% [markdown]
# #***STRING-Q6***

# %%
s="banana"
#aproach1
print(s.count('a'))
#approach2
count=0
for i in s:
  if i=='a':
   count+=1
count
# Out:
# 3
# 3

# %% [markdown]
# #***TUPLE-Q7***

# %%
point = (12, 5)
x,y=point
#point[0]=20 it is immutable so it cannot change('tuple' object does not support item assignment)
print(x)
print(y)
# Out:
# 12
# 5

# %% [markdown]
# #***SET-Q9***

# %%
#approach1
colours = ["red","green","blue","green","red"]
s1=set(colours)
print(s1)
#approach2
setcol=set()
for i in colours:
  setcol.add(i)
print(setcol)
# Out:
# {'blue', 'red', 'green'}
# {'blue', 'red', 'green'}

# %% [markdown]
# #***SET-Q10***

# %%
asha = {"ML","Maths","Python"}
ravi = {"Python","Stats"}
#all subjects
print(asha.union(ravi))
#common subjects
print(asha.intersection(ravi))
# Out:
# {'ML', 'Maths', 'Python', 'Stats'}
# {'Python'}

# %% [markdown]
# #***DICTINONARY***

# %% [markdown]
# #***DICT-Q11,12,13***

# %%
li1 = ["Atomic Habits"]
li2 = ["James Clear"]
li3 = ["2018"]
li4=["100"]
book = {
    "title": "".join(li1),
    "author": "".join(li2),
    "year": "".join(li3),
    "pages": "".join(li4)
}
print(book.items())
#accessing a key which is not defined
print(book.get("publisher"))
# Out:
# dict_items([('title', 'Atomic Habits'), ('author', 'James Clear'), ('year', '2018'), ('pages', '100')])
# None

# %% [markdown]
# #***COMBINED QUESTION-14***

# %%
cities = ["Pune","Delhi","Pune","Surat","Delhi","Pune"]
count=[]
for i in cities:
  count.append(cities.count(i))
#a part
s1=set(cities)
print(s1)
dict1={}
for i in s1:
  dict1[i]=cities.count(i)
print(dict1)
# Out:
# {'Surat', 'Delhi', 'Pune'}
# {'Surat': 1, 'Delhi': 2, 'Pune': 3}
